# %%
from util import *
import matplotlib.pyplot as plt
import seaborn as ses

# %%
pd.get_option("max_row")
pd.set_option("max_row",500)

# %%
trans_reader = pd.read_csv("../data/exist_cancel_user_transactions.csv",iterator=True,index_col=0)

# %%
part_trans = trans_reader.get_chunk(30000)

# %%
msnos = part_trans.msno.unique()

# %%
_p = part_trans[part_trans.msno==msnos[150]]
_p
# Out:
#                                                   msno  payment_method_id  \
# 17283710  ++ny9gX4wM/1tNrLg/FsJPh0bLPPuY5mscc3zhnRYP8=                 41
# 19593750  ++ny9gX4wM/1tNrLg/FsJPh0bLPPuY5mscc3zhnRYP8=                 41
# 6726920   ++ny9gX4wM/1tNrLg/FsJPh0bLPPuY5mscc3zhnRYP8=                 41
# 17712167  ++ny9gX4wM/1tNrLg/FsJPh0bLPPuY5mscc3zhnRYP8=                 41
# 6948276   ++ny9gX4wM/1tNrLg/FsJPh0bLPPuY5mscc3zhnRYP8=                 41
# 4435066   ++ny9gX4wM/1tNrLg/FsJPh0bLPPuY5mscc3zhnRYP8=                 41
# 10939356  ++ny9gX4wM/1tNrLg/FsJPh0bLPPuY5mscc3zhnRYP8=                 41
#
#           payment_plan_days  plan_list_price  actual_amount_paid  \
# 17283710                 30              149                 149
# 19593750                 30              149                 149
# 6726920                  30              149                 149
# 17712167                 30              149                 149
# ...

# %%
transdata_max = part_trans.groupby("transaction_date").max().reset_index()[["msno","transaction_date"]]

# %%
ind = pd.to_datetime(transdata_max.transaction_date.astype(str)) < pd.Timestamp("20160630")

# %%
pre_part_msno = transdata_max[ind].msno.unique()
aft_part_msno = transdata_max[~ind].msno.unique()

# %%
part_trans[np.in1d(part_trans.msno,aft_part_msno)]
# Out:
#                                                   msno  payment_method_id  \
# 17088625  +55j7X02BQ0mB1qqAIfVmn1zEvcCtqI0X+c9UtgDRRw=                 40
# 11513630  +55j7X02BQ0mB1qqAIfVmn1zEvcCtqI0X+c9UtgDRRw=                 40
# 14757066  +55j7X02BQ0mB1qqAIfVmn1zEvcCtqI0X+c9UtgDRRw=                 40
# 3628692   +55j7X02BQ0mB1qqAIfVmn1zEvcCtqI0X+c9UtgDRRw=                 40
# 12512095  +55j7X02BQ0mB1qqAIfVmn1zEvcCtqI0X+c9UtgDRRw=                 40
# 2481112   +55j7X02BQ0mB1qqAIfVmn1zEvcCtqI0X+c9UtgDRRw=                 40
# 5070697   +55j7X02BQ0mB1qqAIfVmn1zEvcCtqI0X+c9UtgDRRw=                 40
# 14474730  +55j7X02BQ0mB1qqAIfVmn1zEvcCtqI0X+c9UtgDRRw=                 40
# 5883500   +55j7X02BQ0mB1qqAIfVmn1zEvcCtqI0X+c9UtgDRRw=                 40
# 10529803  +55j7X02BQ0mB1qqAIfVmn1zEvcCtqI0X+c9UtgDRRw=                 40
# 10903167  +55j7X02BQ0mB1qqAIfVmn1zEvcCtqI0X+c9UtgDRRw=                 40
# 15912749  +55j7X02BQ0mB1qqAIfVmn1zEvcCtqI0X+c9UtgDRRw=                 40
# ...
